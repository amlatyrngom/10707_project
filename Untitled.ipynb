# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
L_old =  [4.9099, 4.3096,
4.0691, 4.0567,
3.7836, 3.9503,
3.6199, 3.9107,
3.5111, 3.8849,
3.4321, 3.8864,
3.3719, 3.8931,
3.3229, 3.8939,
3.2876, 3.9096,
3.2555, 3.9032,
3.2267, 3.9057,
3.2022, 3.9163,
3.1840, 3.9297]

L = [
    5.846, 5.140,
    4.775, 4.391,
    4.173, 4.116,
    3.912, 4.043,
    3.766, 3.992,
    3.654, 3.974,
    3.577, 4.003,
    3.521, 3.961,
    3.467, 3.980,
    3.429, 3.974,
    3.399, 3.977,
    3.365, 3.991,
    3.345, 4.018,
]

# %%
train = [L[2*i] for i in range(len(L) // 2)]
val = [L[2*i + 1] for i in range(len(L) // 2)]
df = pd.DataFrame({"Training" : train, "Validation": val, "Epoch": [i for i in range(len(L) // 2)]})
plt.plot("Epoch", "Training", data=df, color="blue")
plt.plot("Epoch", "Validation", data=df, color="orange")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Average Cross Entropy")
plt.title("Training and Validation Loss")
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss')

# %% [markdown]
# test3 --> dog is running through the water
# test6 --> two girls are playing in the grass
# test8 --> man in red shirt is standing on the street
# test9 --> man is climbing rock

# %% [markdown]
# BLEU-1: 0.553962
# BLEU-2: 0.302612
# BLEU-3: 0.206420
# BLEU-4: 0.094291
